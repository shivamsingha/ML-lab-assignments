# %%
import pandas as pd

# %%
df = pd.read_csv('statedata.csv')

# %%
df.head()
# Out:
#          Date  State  Confirmed Cases  Active Cases  Cured/Discharged
# 0  02/04/2020  Assam                1             1                 0
# 1  03/04/2020  Assam               16            16                 0
# 2  04/04/2020  Assam               24            24                 0
# 3  05/04/2020  Assam               24            24                 0
# 4  06/04/2020  Assam               26            26                 0

# %%
cleaned_df = df.drop(columns=['State', 'Cured/Discharged', 'Confirmed Cases'])
cleaned_df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/lz/59k2qx7s1nj2jp9mcwww5bd80000gn/T/ipykernel_5041/1787454874.py:2: UserWarning: Parsing '13/04/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cleaned_df['Date'] = pd.to_datetime(df['Date'])
# /var/folders/lz/59k2qx7s1nj2jp9mcwww5bd80000gn/T/ipykernel_5041/1787454874.py:2: UserWarning: Parsing '14/04/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cleaned_df['Date'] = pd.to_datetime(df['Date'])
# /var/folders/lz/59k2qx7s1nj2jp9mcwww5bd80000gn/T/ipykernel_5041/1787454874.py:2: UserWarning: Parsing '15/04/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cleaned_df['Date'] = pd.to_datetime(df['Date'])
# ...

# %%
cleaned_df.head()
# Out:
#         Date  Active Cases
# 0 2020-02-04             1
# 1 2020-03-04            16
# 2 2020-04-04            24
# 3 2020-05-04            24
# 4 2020-06-04            26

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 10))
plt.scatter(df['Date'], df['Active Cases'])

# %% [markdown]
# Finding the Peak Point

# %%
peakValue = df['Active Cases'].max()
peakValue
# Out:
# 56295

# %%
# Finding the index of the peak value

# %%
peakValueIndex = df['Active Cases'].idxmax()
peakValueIndex
# Out:
# 414

# %%
result = df.iloc[peakValueIndex]
print("Peak point of Active Cases\n\n", result)
# Out:
# Peak point of Active Cases
#
#  Date                30/05/2021
# State                    Assam
# Confirmed Cases         403623
# Active Cases             56295
# Cured/Discharged        344083
# Name: 414, dtype: object
